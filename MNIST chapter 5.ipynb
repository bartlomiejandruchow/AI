# %% [markdown]
# <a href="https://colab.research.google.com/github/bartlomiejandruchow/AI/blob/main/MNIST%20chapter%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MNIST
from keras.datasets import mnist
import numpy as np

(train_data, train_labels), _ = mnist.load_data()

train_data = train_data.reshape((60000, 28*28))
train_data = train_data.astype("float32") / 255

train_images_baseline = np.copy(train_data)

train_images_with_noise_channels = np.concatenate(
    [train_data, np.random.random((len(train_data),784))],axis=1
    )
train_images_with_zeros_channels = np.concatenate(
    [train_data, np.zeros((len(train_data),784))],axis=1
)

# %%
import keras
from keras import layers

def get_model():
  model = keras.Sequential(
      [
          layers.Dense(512, activation="relu"),
          layers.Dense(10, activation="softmax"),
      ]
  )
  model.compile(
      optimizer = "adam",
      loss = "sparse_categorical_crossentropy",
      metrics = ["accuracy"]
  )
  return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels,
    train_labels,
    epochs = 10,
    batch_size = 128,
    validation_split = 0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7787 - loss: 0.7175 - val_accuracy: 0.9147 - val_loss: 0.2728
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9259 - loss: 0.2489 - val_accuracy: 0.9467 - val_loss: 0.1889
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9537 - loss: 0.1573 - val_accuracy: 0.9485 - val_loss: 0.1703
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9684 - loss: 0.1095 - val_accuracy: 0.9514 - val_loss: 0.1621
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9792 - loss: 0.0746 - val_accuracy: 0.9581 - val_loss: 0.1405
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9843 - loss: 0.0539 - val_accuracy: 0.9594 - val_loss: 0.1389
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9895 - loss: 0.0392 - val_accuracy: 0.9588 - val_loss: 0.1416
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9931 - loss: 0.0276 - val_accuracy: 0.9632 - val_loss: 0.1286
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9962 - loss: 0.0167 - val_accuracy: 0.9653 - val_loss: 0.1324
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9990 - loss: 0.0095 - val_accuracy: 0.9638 - val_loss: 0.1368

# %%
model = get_model()
history_baseline = model.fit(
    train_images_baseline,
    train_labels,
    epochs = 10,
    batch_size = 128,
    validation_split = 0.2
)

# %%
model = get_model()
history_zeros = model.fit(
    train_images_with_zeros_channels,
    train_labels,
    epochs = 10,
    batch_size = 128,
    validation_split = 0.2
)

# %%
import matplotlib.pyplot as plt

val_acc_noise = history_noise.history['val_accuracy']
val_acc_zeros = history_zeros.history['val_accuracy']
val_acc_baseline = history_baseline.history['val_accuracy']
epochs = range(1, 11)
plt.plot(
    epochs,
    val_acc_noise,
    "b--",
    label = "Validation Accuracy With Noise",
)
plt.plot(
    epochs,
    val_acc_zeros,
    "r--",
    label = "Validation Accuracy With Zeros",
)
plt.plot(
    epochs,
    val_acc_baseline,
    "g--",
    label = "Validation Accuracy With Baseline",
)
plt.title("Validation Accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# Randomly shuffled labels

import keras
from keras import layers
import numpy as np
from keras.datasets import mnist

(train_data, train_labels), _ = mnist.load_data()

train_data = train_data.reshape((60000, 28 * 28))
train_data = train_data.astype("float32") / 255

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

model.compile(
    optimizer= keras.optimizers.RMSprop(learning_rate=1e-2), #"adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.fit(
    train_data,
    random_train_labels,
    epochs = 100,
    batch_size = 128,
    validation_split = 0.2,
)

# %%
#Increasing model capacity

import keras
from keras import layers
import numpy as np
from keras.datasets import mnist
import matplotlib.pyplot as plt

(train_data, train_labels), _ = mnist.load_data()

train_data = train_data.reshape((60000, 28 * 28))
train_data = train_data.astype("float32") / 255


model = keras.Sequential(
    [
        layers.Dense(10, activation="softmax"),
    ]
)

model.compile(
    optimizer= "rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history_model = model.fit(
    train_data,
    train_labels,
    epochs = 20,
    batch_size = 128,
    validation_split = 0.2,
)

val_loss = history_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label = "Validation Loss")
plt.title("Validation Loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7339 - loss: 1.0416 - val_accuracy: 0.9055 - val_loss: 0.3582
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9001 - loss: 0.3641 - val_accuracy: 0.9153 - val_loss: 0.3096
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9114 - loss: 0.3172 - val_accuracy: 0.9192 - val_loss: 0.2915
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9151 - loss: 0.3086 - val_accuracy: 0.9223 - val_loss: 0.2848
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9182 - loss: 0.2959 - val_accuracy: 0.9245 - val_loss: 0.2781
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9195 - loss: 0.2912 - val_accuracy: 0.9251 - val_loss: 0.2754
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9209 - loss: 0.2831 - val_accuracy: 0.9250 - val_loss: 0.2729
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9209 - loss: 0.2804 - val_accuracy: 0.9262 - val_loss: 0.2705
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9254 - loss: 0.2707 - val_accuracy: 0.9276 - val_loss: 0.2691
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9253 - loss: 0.2688 - val_accuracy: 0.9273 - val_loss: 0.2675
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9258 - loss: 0.2692 - val_accuracy: 0.9287 - val_loss: 0.2658
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9259 - loss: 0.2702 - val_accuracy: 0.9292 - val_loss: 0.2661
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9289 - loss: 0.2629 - val_accuracy: 0.9292 - val_loss: 0.2651
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9271 - loss: 0.2645 - val_accuracy: 0.9292 - val_loss: 0.2634
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9279 - loss: 0.2661 - val_accuracy: 0.9304 - val_loss: 0.2638
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9288 - loss: 0.2602 - val_accuracy: 0.9300 - val_loss: 0.2633
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9281 - loss: 0.2569 - val_accuracy: 0.9288 - val_loss: 0.2657
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9281 - loss: 0.2585 - val_accuracy: 0.9287 - val_loss: 0.2629
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9310 - loss: 0.2543 - val_accuracy: 0.9297 - val_loss: 0.2613
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9302 - loss: 0.2584 - val_accuracy: 0.9309 - val_loss: 0.2625
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-616255175.py in <cell line: 0>()
#      33 )
#      34
# ---> 35 val_loss = history_model.history["val_loss"]
#      36 epochs = range(1, 21)
#      37 plt.plot(epochs, val_loss, "b-", label = "Validation Loss")
#
# AttributeError: 'NoneType' object has no attribute 'history'
