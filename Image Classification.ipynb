# %% [markdown]
# <a href="https://colab.research.google.com/github/bartlomiejandruchow/AI/blob/main/Image%20Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")

# %%
import zipfile

with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
  zip_ref.extractall(".")

# %%
import os, shutil, pathlib

print(os.listdir(download_path))
# Out:
# ['sampleSubmission.csv', 'test1.zip', 'train.zip']

# %%
import os, shutil, pathlib

n = 0
for i in os.listdir(download_path + "/train"):
  n += 1
print(n)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11545/3554800499.py in <cell line: 0>()
#       2
#       3 n = 0
# ----> 4 for i in os.listdir(download_path + "/train"):
#       5   n += 1
#       6 print(n)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.cache/kagglehub/competitions/dogs-vs-cats/train'

# %%
import os, shutil, pathlib

n = 0
for i in os.listdir(download_path + "/train"):
  n += 1
print(n)

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
  for category in ("cat","dog"):
    dir = new_base_dir / subset_name / category
    os.makedirs(dir)
    fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
    for fname in fnames:
      shutil.copyfile(src = original_dir / fname, dst = dir / fname)

make_subset("train", start_index = 0, end_index = 1500)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_523/1906785799.py in <cell line: 0>()
#       2
#       3 n = 0
# ----> 4 for i in os.listdir(download_path + "/train"):
#       5   n += 1
#       6 print(n)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.cache/kagglehub/competitions/dogs-vs-cats/train'
